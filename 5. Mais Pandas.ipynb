# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color: #301E40; border: 0px; -moz-border-radius: 10px; -webkit-border-radius: 10px;">
# <br/><br/>
# <h1 style="font-size: 45px; color: white; align: center;"><center>
# <img src="https://raw.githubusercontent.com/HumbleData/beginners-data-workshop/master/media/humble-data-logo-white-transparent.png" width="250px" /><br/><br/>
# Mais do pandas
# </center></h1>
# </div>

# %% [markdown]
# ***Nota***: este notebook contém células com ***uma*** solução. Lembre-se de que não existe apenas uma solução para um problema!
#
# Você reconhecerá essas células porque começam com **# %**.
#
# Se quiser ver a solução, remova o **#** (pode ser feito com **Ctrl** + **?**) e execute a célula. Se quiser rodar o código da solução, execute a célula novamente.

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Exercício
# </h2><br>
# </div>

# %% [markdown]
# > 1. Importe o pandas (com a convenção mais usada vista no notebook 2).
# > 2. Importe datetime.
# > 3. Importe matplotlib (conforme mostrado no notebook 3.1).
# > 4. Adicione o comando mágico para exibir o gráfico no Jupyter.

# %%
# !cat solutions/05_01.py # mac, linux

# %%
# !type solutions\05_01.py # windows

# %% [markdown]
# Neste notebook vamos usar dados fornecidos pelo [governo do Reino Unido](https://data.gov.uk/dataset/a59198d9-2e24-4816-be1b-c3a1efa02dda/better-training-for-safer-food). Eles são disponibilizados sob a [Licença de Governo Aberto](http://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/).

# %% [markdown]
# >Carregue os dados do ano de 2014 e atribua a df_2014 (caminho: 'data/food_training/training_2014.csv')

# %%
# !cat solutions/05_02.py # mac, linux

# %%
# !type solutions\05_02.py # windows

# %% [markdown]
# >Dê uma olhada nas primeiras linhas de df_2014

# %%
# !cat solutions/05_03.py # mac, linux

# %%
# !type solutions\05_03.py # windows

# %% [markdown]
# Você pode ver que o cabeçalho não está no lugar correto.
#
# Se olhar a documentação, verá que o parâmetro *header* do método read_csv está definido como *infer*. Ele infere o cabeçalho usando a primeira linha (índice *0*).

# %% [markdown]
# >Carregue os dados de 2014 usando o parâmetro header e atribua a df_2014 (será sobrescrito)

# %%
# !cat solutions/05_04.py # mac, linux

# %%
# !type solutions\05_04.py # windows

# %% [markdown]
# >Dê uma olhada nas primeiras linhas de df_2014. Parece melhor, não é?

# %%
# !cat solutions/05_05.py # mac, linux

# %%
# !type solutions\05_05.py # windows

# %% [markdown]
# >Carregue os dados dos anos 2015 e 2016 e atribua a df_2015 e df_2016 (não esqueça do parâmetro!)

# %%
# !cat solutions/05_06.py # mac, linux

# %%
# !type solutions\05_06.py # windows

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Concatenar
# </h2><br>
# </div>

# %% [markdown]
# O Pandas tem uma boa página com documentação sobre [merge (mesclar), join (juntar) e concatenation (concatenação)](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html).

# %% [markdown]
# >Usando a documentação, concatene os 3 dataframes em um, chamado df.

# %%
# !cat solutions/05_07.py # mac, linux

# %%
# !type solutions\05_07.py # windows

# %% [markdown]
# >verifique o formato (shape) de df

# %%
# !cat solutions/05_08.py # mac, linux

# %%
# !type solutions\05_08.py # windows

# %% [markdown]
# >Olhe para os índices de df usando o atributo index.

# %%
# !cat solutions/05_09.py # mac, linux

# %%
#!type solutions\05_09.py # windows

# %% [markdown]
# Podemos ver que o índice não vai de 0 a 265 com passo de 1...
# > Limpe o índice existente e redefina-o usando o método ***reset_index***.
# > Verifique o índice de df.

# %%
# !cat solutions/05_10.py # mac, linux

# %%
# !type solutions\05_10.py # windows

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Removendo colunas
# </h2><br>
# </div>

# %% [markdown]
# >Mostre as informações relativas às colunas de df.

# %%
# !cat solutions/05_11.py # mac, linux

# %%
# !type solutions\05_11.py # windows

# %% [markdown]
# Podemos ver que as duas últimas colunas estão completamente vazias, então as vamos remover.

# %% [markdown]
# >Obtenha a ajuda para o método drop (ou procure a documentação online).

# %%
# !cat solutions/05_12.py # mac, linux

# %%
# !type solutions\05_12.py # windows

# %% [markdown]
# Você pode ver que o valor padrão de *axis* é *0*. Quando é esse o caso, o método olha para as linhas (i.e. *axis 0*) do dataframe.
# No nosso caso queremos remover colunas (i.e. *axis 1*).

# %% [markdown]
# >Remova as duas últimas colunas de df.
# >labels: forneça uma lista com os nomes das colunas
# >Não se esqueça do axis!

# %%
# !cat solutions/05_13.py # mac, linux

# %%
# !type solutions\05_13.py # windows

# %%
df.head()

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Dados textuais
# </h2><br>
# </div>

# %% [markdown]
# Para [trabalhar com dados textuais](https://pandas.pydata.org/pandas-docs/version/0.23.4/text.html), usaremos o atributo ***str*** para acessar os métodos (ex.: df['col'].str.replace('-', ' ')).
# Precisaremos usar esse atributo em diferentes casos, mas antes vamos olhar a coluna **Location** (Localização).
# >Mostre os valores únicos da coluna **Location** (Localização).

# %%
# !cat solutions/05_14.py # mac, linux

# %%
# !type solutions\05_14.py # windows

# %% [markdown]
# Você pode ver que cidades e países estão separados por ponto e vírgula (mesmo que alguns valores faltem). Vamos dividir a coluna ***Location*** (Localização).
# >Tente dividir a coluna ***Location*** (Localização) pelo ponto e vírgula.
# >Você pode checar a [documentação](https://pandas.pydata.org/pandas-docs/version/0.23.4/text.html) fornecida antes ou a documentação de [Series.str.split](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).

# %%
# !cat solutions/05_15.py # mac, linux

# %%
# !type solutions\05_15.py # windows

# %% [markdown]
# Isso retorna uma lista com os itens antes e depois do ponto e vírgula.
# Tente novamente dividir a coluna ***Location*** (Localização), mas expanda os resultados para obter as partes em colunas diferentes.

# %%
# !cat solutions/05_16.py # mac, linux

# %%
# !type solutions\05_16.py # windows

# %% [markdown]
# >Crie as colunas ***city*** (cidade) e ***country*** (país) em df usando essa divisão.

# %%
# !cat solutions/05_17.py # mac, linux

# %%
# !type solutions\05_17.py # windows

# %% [markdown]
# >Remova a coluna ***Location***.

# %%
# !cat solutions/05_18.py # mac, linux

# %%
# !type solutions\05_18.py # windows

# %%
df.head()

# %% [markdown]
# >Obtenha o número de valores únicos na coluna ***country***.

# %%
# !cat solutions/05_19.py # mac, linux

# %%
# !type solutions\05_19.py # windows

# %% [markdown]
# >Verifique a contagem de cada valor único na coluna ***country***.

# %%
# !cat solutions/05_20.py # mac, linux

# %%
# !type solutions\05_20.py # windows

# %% [markdown]
# Podemos ver que alguns países (por ex. Italy) parecem aparecer várias vezes com variações.
# >Use o método strip para remover espaços extras no início e fim dos nomes de cidades e países.

# %%
# !cat solutions/05_21.py # mac, linux

# %%
# !type solutions\05_21.py # windows

# %% [markdown]
# >Verifique novamente o número de valores únicos na coluna country

# %%
# !cat solutions/05_22.py # mac, linux

# %%
# !type solutions\05_22.py # windows

# %% [markdown]
# >Veja as linhas onde o ***country*** é Portugal.
# O que você nota sobre a coluna ***city***?

# %%
# !cat solutions/05_23.py # mac, linux

# %%
# !type solutions\05_23.py # windows

# %% [markdown]
# >Coloque a coluna ***city*** em letras minúsculas (não esqueça de reatribuir a coluna **city**).

# %%
# !cat solutions/05_24.py # mac, linux

# %%
# !type solutions\05_24.py # windows

# %% [markdown]
# >Veja as linhas onde a coluna ***city*** contém ' ***/*** '.

# %%
# !cat solutions/05_25.py # mac, linux

# %%
# !type solutions\05_25.py # windows

# %% [markdown]
# Vamos decidir que queremos apenas uma cidade por linha. Podemos manter apenas a parte antes da barra.
# >Substitua a string contendo a barra (i.e. ***/***) pela cidade que aparece antes da barra na coluna ***city***.
# >Você terá de usar uma [expressão regular](https://docs.python.org/3/howto/regex.html#repeating-things).
# >Você pode testar sua expressão regular em https://regex101.com.

# %%
# !cat ../solutions/05_26.py # mac, linux

# %%
# !type ..\solutions\05_26.py # windows

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Estrutura Map
# </h2><br>
# </div>

# %%
df['country'].value_counts()

# %% [markdown]
# Vimos que alguns países foram preenchidos com o código do país e outros com o nome. Vamos padronizar tudo para o mesmo formato.
# Podemos fazer isso mapeando um dicionário para a coluna. Ele substituirá a ***chave*** pelo valor correspondente.
# >Complete o código abaixo para substituir os códigos de país pelo nome do país.
# >Note que usamos uma máscara porque queremos substituir apenas certos valores da série.

# %%
dict_code = {'BG':'Bulgaria', 'CZ':'Czech Republic', 'IT':'Italy', 'GR':'Greece', 'SI':'Slovenia', 'UK':'United Kingdom'}

df.loc[df['country'].isin(dict_codes.keys()), 'country'] =

# %%
# !cat ../solutions/05_27.py # mac, linux

# %%
# !type ..\solutions\05_27.py # windows

# %%
df['country'].value_counts(dropna=False)

# %% [markdown]
# Alguns valores de city são desconhecidos.
# >Veja os valores de ***country*** onde a ***city*** é ***unknown***.

# %%
df['city'].value_counts()

# %%
# !cat ../solutions/05_28.py # mac, linux

# %%
# !type ..\solutions\05_28.py # windows

# %% [markdown]
# >Complete o código abaixo para substituir o valor ***unknown*** na coluna ***city*** pela capital do país correspondente.

# %%
dict_capitals = {'Denmark':'copenhague', 'France':'paris', 'Italy':'rome', 'Spain':'madrid', 'United Kingdom':'london'}

df.loc[df['city'] == 'unknown', 'city'] = df.loc[df['city'] == 'unknown', 'country'].

# %%
# !cat ../solutions/05_29.py # mac, linux

# %%
# !type ..\solutions\05_29.py # windows

# %% [markdown]
# Muitos países estão faltando mas podemos preenchê-los usando as cidades.
# Podemos criar um dicionário de cidades e seus países correspondentes usando as linhas onde o ***country*** não é nulo.

# %%
dict_cities = df.loc[df['country'].notnull(), ['city', 'country']].set_index('city').to_dict()['country']

# %% [markdown]
# Agora queremos verificar se todas as cidades que precisamos estão no nosso dicionário.
# >Subtraindo as chaves do dicionário do conjunto de valores da coluna ***city*** encontre quais cidades estão na coluna ***city*** mas não nas chaves do dicionário.

# %%
# !cat ../solutions/05_30.py # mac, linux

# %%
# !type ..\solutions\05_30.py # windows

# %% [markdown]
# >Sabendo que Bristol fica no Reino Unido, Gothenburg na Suécia, Graz na Áustria, Lyon na França, Murcia na Espanha e Parma na Itália, adicione esses pares chave-valor ao dicionário ***dict_cities***.
# >Você pode adicionar cada par individualmente ou atualizar o dict_cities com outro dicionário.

# %%
# !cat ../solutions/05_31.py # mac, linux

# %%
# !type ..\solutions\05_31.py # windows

# %% [markdown]
# >Use este dicionário para preencher alguns dos países que estão faltando.

# %%
# !cat ../solutions/05_32.py # mac, linux

# %%
# !type ..\solutions\05_32.py # windows

# %% [markdown]
# >Obtenha a contagem dos diferentes valores da coluna ***country*** mostrando também os valores NaN.

# %%
# !cat ../solutions/05_33.py # mac, linux

# %%
# !type ..\solutions\05_33.py # windows

# %% [markdown]
# Vemos que há apenas 4 valores NaN. Eles correspondem a entradas de dados incorretas que poderíamos corrigir manualmente. Sinta-se à vontade para adicionar algumas chamadas abaixo e tentar!

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Função Apply
# </h2><br>
# </div>

# %% [markdown]
# >Escreva uma função que retorne ***single*** se o valor passado for 1 e ***multiple*** caso contrário.

# %%
# !cat ../solutions/05_34.py # mac, linux

# %%
# !type ..\solutions\05_34.py # windows

# %% [markdown]
# >Aplique essa função à coluna ***Attendees*** (participantes).

# %%
# !cat ../solutions/05_35.py # mac, linux

# %%
# !type ..\solutions\05_35.py # windows

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Join
# </h2><br>
# </div>

# %% [markdown]
# >Carregue os dados de idiomas e atribua a languages (caminho: 'data/food_training/languages.csv')

# %%
# !cat ../solutions/05_36.py # mac, linux

# %%
# !type ..\solutions\05_36.py # windows

# %%
languages.head()

# %% [markdown]
# >Faça um join entre df e languages para adicionar a informação de idioma a df.
# >Você pode consultar a página sobre [merge (mesclar), join (juntar) e concatenation (concatenação)](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html) ou a [documentação](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html) do método merge (mesclar).

# %%
# !cat ../solutions/05_37.py # mac, linux

# %%
# !type ..\solutions\05_37.py # windows

# %% [markdown]
# >Remova a coluna ***Country*** de df.

# %%
# !cat ../solutions/05_38.py # mac, linux

# %%
# !type ..\solutions\05_38.py # windows

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Datas e horas
# </h2><br>
# </div>

# %% [markdown]
#  >Verifique o dtype da coluna ***DateFrom***.

# %%
# !cat ../solutions/05_39.py # mac, linux

# %%
# !type ..\solutions\05_39.py # windows

# %% [markdown]
# ***DateFrom*** e ***DateTo*** são objetos.
# >Converta essas duas colunas para o formato ***datetime***.

# %%
# !cat ../solutions/05_40.py # mac, linux

# %%
# !type ..\solutions\05_40.py # windows

# %% [markdown]
# Nota: poderíamos ter usado o parâmetro *parse_dates* ao carregar os dados.
# Agora podemos usar essas colunas para filtrar ou fazer cálculos.
# >Mostre as linhas onde o treinamento começou após 1º de fevereiro de 2017.

# %%
# !cat ../solutions/05_41.py # mac, linux

# %%
# !type ..\solutions\05_41.py # windows

# %% [markdown]
# >Crie uma coluna ***duration*** com a duração do treinamento.

# %%
# !cat ../solutions/05_42.py # mac, linux

# %%
# !type ..\solutions\05_42.py # windows

# %% [markdown]
# >Crie uma coluna ***month*** indicando em que mês o treinamento começou.
# >Plote um histograma da coluna ***month***.

# %%
# !cat ../solutions/05_43.py # mac, linux

# %%
# !type ..\solutions\05_43.py # windows

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Ordenando Valores
# </h2><br>
# </div>

# %% [markdown]
# >Ordene df em ordem alfabética por ***city***.

# %%
# !cat ../solutions/05_44.py # mac, linux

# %%
# !type ..\solutions\05_44.py # windows

# %% [markdown]
# >Ordene df por ***duration*** (duração) ascendente e por número de ***Attendees*** (participantes) em ordem decrescente.

# %%
# !cat ../solutions/05_45.py # mac, linux

# %%
# !type ..\solutions\05_45.py # windows

# %% [markdown]
# Podemos ver que houve alguns problemas com entradas de datas...

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning" style="padding: 0px; padding-left: 20px; padding-top: 5px;"><h2 style="color: #301E40">
# Group By
# </h2><br>
# </div>

# %% [markdown]
# >Agrupe df por ***city***. Atribua os dados agrupados a df_gr.

# %%
# !cat ../solutions/05_46.py # mac, linux

# %%
# !type ..\solutions\05_46.py # windows

# %% [markdown]
# >Obtenha a média de ***Attendees*** (participantes) para os dados agrupados.

# %%
# !cat ../solutions/05_47.py
 # mac, linux

# %%
# !type ..\solutions\05_47.py
 # windows
